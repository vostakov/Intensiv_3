# %% [markdown]
# 0. Отсортировать данные, создать/обучить модель (Лучше одну из предложенных в презентации, но их надо настраивать), научить её предсказывать цены арматуры на >10 недель вперёд, но выдавать пользователю надо от 1 до 6 (>=1 И =<6)

# %% [markdown]
# 1. Необходимо разработать модель, которая по истории цен и дополнительных данных за период [1,T] делает рекомендацию по объему тендера на арматуру для недели T.
#
# Тоесть помимо изученных машиной данных, создаётся дополнительный временной ряд (от стартовой точки 1 до точки Т), после чего она уже делает рекомендацию по объёму тендера для недели Т
#
# Неделя Т это крайняя неделя, используемая для подготовки рекомендации

# %% [markdown]
# 2. Рекомендация на N недель фиксирует цену на N недель, следующий тендер будет проведен на неделе T+N. Считаем, что тендеры проводятся по понедельникам, для прогноза на следующие N недель оперировать можно историческими данными до понедельника включительно.
#
# После прогнозирования первой рекомендации (От 1 до Т), пользователь вводит количество следующих недель, тоесть число N недель (>=1 и =<6) и фиксирует цену, чтобы по ней предугадать цену. Далее считается, что тендеры проводят по понедельникам, поэтому понедельник следующей недели тоже учитывается.

# %% [markdown]
# 3. На основе полученной модели, необходимо разработать приложение для пользователя (категорийного менеджера) с интуитивно понятным интерфейсом
#
# Тут всё и так понятно. На модели делается приложение с нормальным интерфейсом (Типо экселя)
