# %% [markdown]
# 1. Понять данные и обработать их (Каждый индивидуально)
# (первое предположение, что каждый пункт это средняя цена за неделю, так как суммарно пунктов ~430, тоесть ~8 лет, которые и взяты в данных)

# %% [markdown]
# 2. Бейзлайн (Индивидуально)
# Сделать свою или использовать существующую модель (Статистические модели, Нейронки, Арима, Лог-Регрессия)

# %% [markdown]
# 3. Посмотреть все бейзлайны, подумать и сделать что-то совместно

# %% [markdown]
# 4. Сделать общую модель с лучшими результатами (Желательно две)

# %% [markdown]
# 5. на основе модели сделать приложение с дизайном и интерфейсом, типо экселя
